# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('Strict_regulations_for_Semantics/combined_all_filtered_constraints.csv')

# Define the indices to filter (subtract 3 from each)
original_indices = [3, 4, 5, 9, 14, 15, 16, 28, 42, 44, 47, 53, 20, 57, 61, 84, 91, 94, 104, 48, 182, 200, 214, 227, 247, 253, 282, 292, 293, 297, 323, 329, 347, 352, 366, 446, 458, 484, 496, 523, 567, 583, 733, 799, 836, 968, 1086, 1212, 1257, 1409, 1511, 1616, 1640, 1642, 1656, 1658, 1723, 1904, 1955, 2001]
adjusted_indices = [idx - 3 for idx in original_indices]

# Filter the dataframe by adjusted indices
filtered_df = df.iloc[adjusted_indices]

# Save filtered data to the specified directory
output_path = '/Users/li/Library/CloudStorage/OneDrive-UniversityofMaryland/PhD research/Python/LLM/Extract_regulations/Final_selection/filtered_constraints_selected.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Filtered {len(filtered_df)} rows from {len(df)} total rows")
print(f"Original indices: {original_indices[:10]}... (showing first 10)")
print(f"Adjusted indices: {adjusted_indices[:10]}... (showing first 10)")
print(f"Saved to '{output_path}'")
# Out:
# Filtered 60 rows from 2107 total rows
# Original indices: [3, 4, 5, 9, 14, 15, 16, 28, 42, 44]... (showing first 10)
# Adjusted indices: [0, 1, 2, 6, 11, 12, 13, 25, 39, 41]... (showing first 10)
# Saved to '/Users/li/Library/CloudStorage/OneDrive-UniversityofMaryland/PhD research/Python/LLM/Extract_regulations/Final_selection/filtered_constraints_selected.csv'
